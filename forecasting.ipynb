# %%
import matplotlib.pyplot as plt

fig = model.plot(forecast)
plt.title("Forecast of Requests for the Next 14 Days")
plt.xlabel("Date")
plt.ylabel("Number of Requests")
plt.tight_layout()
plt.show()
